# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.utils import shuffle
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score

# %%
from sklearn import svm
from sklearn.linear_model import SGDClassifier
from sklearn.neighbors import NearestNeighbors
from sklearn.naive_bayes import GaussianNB
from sklearn import tree

# %%
h0_df = pd.read_csv('Extracted Features Sampling 50/Healthy/h30hz0_features.csv')
h1_df = pd.read_csv('Extracted Features Sampling 50/Healthy/h30hz10_features.csv')
h2_df = pd.read_csv('Extracted Features Sampling 50/Healthy/h30hz20_features.csv')
h3_df = pd.read_csv('Extracted Features Sampling 50/Healthy/h30hz30_features.csv')
h4_df = pd.read_csv('Extracted Features Sampling 50/Healthy/h30hz40_features.csv')
h5_df = pd.read_csv('Extracted Features Sampling 50/Healthy/h30hz50_features.csv')
h6_df = pd.read_csv('Extracted Features Sampling 50/Healthy/h30hz60_features.csv')
h7_df = pd.read_csv('Extracted Features Sampling 50/Healthy/h30hz70_features.csv')
h8_df = pd.read_csv('Extracted Features Sampling 50/Healthy/h30hz80_features.csv')
h9_df = pd.read_csv('Extracted Features Sampling 50/Healthy/h30hz90_features.csv')

# %%
dataframes = [h0_df, h1_df, h2_df, h3_df, h4_df, h5_df, h6_df, h7_df, h8_df, h9_df]
combined_healthy_df = pd.concat(dataframes, ignore_index=True)

# %%
combined_healthy_df.head()
# Out:
#     Mean_S1    RMS_S1  StdDev_S1  Variance_S1  Skewness_S1  Kurtosis_S1  \
# 0  0.211607  3.444974   3.438469    11.823067    -0.500554     0.370793
# 1 -0.345117  5.344704   5.333550    28.446756    -0.028462     0.127516
# 2  0.402666  3.631026   3.608629    13.022207    -0.379755     0.398995
# 3 -0.317764  3.251598   3.236033    10.471913    -1.084147     1.202911
# 4 -0.683565  4.138555   4.081712    16.660375    -0.114544     0.945400
#
#    PeakToPeak_S1  CrestFactor_S1  ShapeFactor_S1  ImpulseFactor_S1  ...  \
# 0       17.32893        2.548330        1.264779          3.223074  ...
# 1       26.38100        2.516903        1.265254          3.184522  ...
# 2       17.42826        2.662262        1.289113          3.431957  ...
# 3       15.27120        2.835585        1.386772          3.932309  ...
# 4       21.42600        2.670497        1.428241          3.814115  ...
#
#    StdDev_S4  Variance_S4  Skewness_S4  Kurtosis_S4  PeakToPeak_S4  \
# 0   2.417927     5.846372     0.276414     1.610202       13.45726
# 1   3.527754    12.445051     0.025310    -0.983499       13.51405
# 2   2.477899     6.139985     0.339464     0.206170       11.32056
# 3   2.235548     4.997673     0.631961    -0.172993        9.79885
# 4   3.146112     9.898018    -0.572981     0.578095       15.92877
#
#    CrestFactor_S4  ShapeFactor_S4  ImpulseFactor_S4  load  label
# 0        2.788989        1.352667          3.772575     0      0
# 1        2.069645        1.182946          2.448278     0      0
# 2        2.422520        1.321233          3.200713     0      0
# 3        2.711126        1.305284          3.538789     0      0
# 4        2.695573        1.246670          3.360491     0      0
#
# [5 rows x 42 columns]

# %%
combined_healthy_df.shape
# Out:
# (19998, 42)

# %%
h0_df.shape, h1_df.shape, h2_df.shape, h3_df.shape, h4_df.shape, h5_df.shape, h6_df.shape, h7_df.shape, h8_df.shape, h9_df.shape,
# Out:
# ((1776, 42),
#  (1858, 42),
#  (1858, 42),
#  (2124, 42),
#  (2012, 42),
#  (2216, 42),
#  (1996, 42),
#  (2027, 42),
#  (1996, 42),
#  (2135, 42))

# %%
type(combined_healthy_df)
# Out:
# pandas.core.frame.DataFrame

# %%
healthy_twentyPercent_sample = combined_healthy_df.sample(frac=0.1, random_state=1)
healthy_eightyPercent_sample = combined_healthy_df.drop(healthy_twentyPercent_sample.index)

# %%
healthy_twentyPercent_sample.shape, healthy_eightyPercent_sample.shape
# Out:
# ((2000, 42), (17998, 42))

# %%
b0_df = pd.read_csv('Extracted Features Sampling 50/Faulty/b30hz0_features.csv')
b1_df = pd.read_csv('Extracted Features Sampling 50/Faulty/b30hz10_features.csv')
b2_df = pd.read_csv('Extracted Features Sampling 50/Faulty/b30hz20_features.csv')
b3_df = pd.read_csv('Extracted Features Sampling 50/Faulty/b30hz30_features.csv')
b4_df = pd.read_csv('Extracted Features Sampling 50/Faulty/b30hz40_features.csv')
b5_df = pd.read_csv('Extracted Features Sampling 50/Faulty/b30hz50_features.csv')
b6_df = pd.read_csv('Extracted Features Sampling 50/Faulty/b30hz60_features.csv')
b7_df = pd.read_csv('Extracted Features Sampling 50/Faulty/b30hz70_features.csv')
b8_df = pd.read_csv('Extracted Features Sampling 50/Faulty/b30hz80_features.csv')
b9_df = pd.read_csv('Extracted Features Sampling 50/Faulty/b30hz90_features.csv')

# %%
dataframes = [b0_df, b1_df, b2_df, b3_df, b4_df, b5_df, b6_df, b7_df, b8_df, b9_df]
combined_faulty_df = pd.concat(dataframes, ignore_index=True)

# %%
combined_faulty_df.shape
# Out:
# (20102, 42)

# %%
b0_df.shape, b1_df.shape, b2_df.shape, b3_df.shape, b4_df.shape, b5_df.shape, b6_df.shape, b7_df.shape, b8_df.shape, b9_df.shape,
# Out:
# ((1766, 42),
#  (2232, 42),
#  (2288, 42),
#  (1797, 42),
#  (1889, 42),
#  (1884, 42),
#  (1909, 42),
#  (2017, 42),
#  (2206, 42),
#  (2114, 42))

# %%
combined_faulty_df.shape
# Out:
# (20102, 42)

# %%
faulty_twentyPercent_sample = combined_faulty_df.sample(frac=0.1, random_state=1)
faulty_eightyPercent_sample = combined_faulty_df.drop(faulty_twentyPercent_sample.index)

# %%
faulty_twentyPercent_sample.shape, faulty_eightyPercent_sample.shape
# Out:
# ((2010, 42), (18092, 42))

# %%
eighty_percent_training_data = [healthy_eightyPercent_sample, faulty_eightyPercent_sample]
eighty_percent_training_data = pd.concat(eighty_percent_training_data, ignore_index=True)

twenty_percent_testing_data = [healthy_twentyPercent_sample, faulty_twentyPercent_sample]
twenty_percent_testing_data = pd.concat(twenty_percent_testing_data, ignore_index=True)

# %%
eighty_percent_training_data.shape, twenty_percent_testing_data.shape
# Out:
# ((36090, 42), (4010, 42))

# %%
eighty_percent_training_data.to_csv('training_data.csv', index=False)
twenty_percent_testing_data.to_csv('testing_data.csv', index=False)
