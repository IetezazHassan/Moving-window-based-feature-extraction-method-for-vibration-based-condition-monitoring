# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.utils import shuffle
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score

# %%
from sklearn import svm
from sklearn.linear_model import SGDClassifier
from sklearn.neighbors import NearestNeighbors
from sklearn.naive_bayes import GaussianNB
from sklearn import tree

# %%
h0_df = pd.read_csv('Extracted Features Sampling 20/Healthy/h30hz0_features.csv')
h1_df = pd.read_csv('Extracted Features Sampling 20/Healthy/h30hz10_features.csv')
h2_df = pd.read_csv('Extracted Features Sampling 20/Healthy/h30hz20_features.csv')
h3_df = pd.read_csv('Extracted Features Sampling 20/Healthy/h30hz30_features.csv')
h4_df = pd.read_csv('Extracted Features Sampling 20/Healthy/h30hz40_features.csv')
h5_df = pd.read_csv('Extracted Features Sampling 20/Healthy/h30hz50_features.csv')
h6_df = pd.read_csv('Extracted Features Sampling 20/Healthy/h30hz60_features.csv')
h7_df = pd.read_csv('Extracted Features Sampling 20/Healthy/h30hz70_features.csv')
h8_df = pd.read_csv('Extracted Features Sampling 20/Healthy/h30hz80_features.csv')
h9_df = pd.read_csv('Extracted Features Sampling 20/Healthy/h30hz90_features.csv')

# %%
dataframes = [h0_df, h1_df, h2_df, h3_df, h4_df, h5_df, h6_df, h7_df, h8_df, h9_df]
combined_healthy_df = pd.concat(dataframes, ignore_index=True)

# %%
combined_healthy_df.head()
# Out:
#     Mean_S1    RMS_S1  StdDev_S1  Variance_S1  Skewness_S1  Kurtosis_S1  \
# 0 -0.090854  4.390240   4.389300    19.265955    -0.196031    -0.429339
# 1 -0.162938  2.867394   2.862761     8.195401    -0.559332    -0.834754
# 2  0.422148  4.657949   4.638780    21.518279     0.080212     2.702180
# 3 -0.075516  4.042575   4.041870    16.336710    -0.787787     0.361863
# 4 -0.426614  5.962315   5.947033    35.367203    -0.056694    -0.785576
#
#    PeakToPeak_S1  CrestFactor_S1  ShapeFactor_S1  ImpulseFactor_S1  ...  \
# 0       17.32893        1.999647        1.244766          2.489093  ...
# 1        9.62366        1.965579        1.189309          2.337681  ...
# 2       25.19730        2.887988        1.457271          4.208581  ...
# 3       16.51653        2.669685        1.257839          3.358034  ...
# 4       21.22748        2.168436        1.187290          2.574563  ...
#
#    StdDev_S4  Variance_S4  Skewness_S4  Kurtosis_S4  PeakToPeak_S4  \
# 0   3.009587     9.057617    -0.076544     0.703821       13.45726
# 1   1.896211     3.595616    -0.535434     0.436590        8.40686
# 2   3.125114     9.766336     0.627622    -0.508180       11.75914
# 3   2.978369     8.870681     0.028583    -1.108104        9.59447
# 4   3.669873    13.467965    -0.154631    -0.869312       13.51405
#
#    CrestFactor_S4  ShapeFactor_S4  ImpulseFactor_S4  load  label
# 0        2.148786        1.333817          2.866088     0      0
# 1        2.762748        1.280877          3.538741     0      0
# 2        2.264056        1.262492          2.858353     0      0
# 3        1.620373        1.180184          1.912338     0      0
# 4        1.977412        1.198579          2.370084     0      0
#
# [5 rows x 42 columns]

# %%
combined_healthy_df.shape
# Out:
# (50006, 42)

# %%
h0_df.shape, h1_df.shape, h2_df.shape, h3_df.shape, h4_df.shape, h5_df.shape, h6_df.shape, h7_df.shape, h8_df.shape, h9_df.shape,
# Out:
# ((4441, 42),
#  (4646, 42),
#  (4646, 42),
#  (5312, 42),
#  (5030, 42),
#  (5542, 42),
#  (4992, 42),
#  (5068, 42),
#  (4992, 42),
#  (5337, 42))

# %%
type(combined_healthy_df)
# Out:
# pandas.core.frame.DataFrame

# %%
healthy_twentyPercent_sample = combined_healthy_df.sample(frac=0.1, random_state=1)
healthy_eightyPercent_sample = combined_healthy_df.drop(healthy_twentyPercent_sample.index)

# %%
healthy_twentyPercent_sample.shape, healthy_eightyPercent_sample.shape
# Out:
# ((5001, 42), (45005, 42))

# %%
b0_df = pd.read_csv('Extracted Features Sampling 20/Faulty/b30hz0_features.csv')
b1_df = pd.read_csv('Extracted Features Sampling 20/Faulty/b30hz10_features.csv')
b2_df = pd.read_csv('Extracted Features Sampling 20/Faulty/b30hz20_features.csv')
b3_df = pd.read_csv('Extracted Features Sampling 20/Faulty/b30hz30_features.csv')
b4_df = pd.read_csv('Extracted Features Sampling 20/Faulty/b30hz40_features.csv')
b5_df = pd.read_csv('Extracted Features Sampling 20/Faulty/b30hz50_features.csv')
b6_df = pd.read_csv('Extracted Features Sampling 20/Faulty/b30hz60_features.csv')
b7_df = pd.read_csv('Extracted Features Sampling 20/Faulty/b30hz70_features.csv')
b8_df = pd.read_csv('Extracted Features Sampling 20/Faulty/b30hz80_features.csv')
b9_df = pd.read_csv('Extracted Features Sampling 20/Faulty/b30hz90_features.csv')

# %%
dataframes = [b0_df, b1_df, b2_df, b3_df, b4_df, b5_df, b6_df, b7_df, b8_df, b9_df]
combined_faulty_df = pd.concat(dataframes, ignore_index=True)

# %%
combined_faulty_df.shape
# Out:
# (50261, 42)

# %%
b0_df.shape, b1_df.shape, b2_df.shape, b3_df.shape, b4_df.shape, b5_df.shape, b6_df.shape, b7_df.shape, b8_df.shape, b9_df.shape,
# Out:
# ((4416, 42),
#  (5580, 42),
#  (5721, 42),
#  (4492, 42),
#  (4723, 42),
#  (4710, 42),
#  (4774, 42),
#  (5043, 42),
#  (5516, 42),
#  (5286, 42))

# %%
combined_faulty_df.shape
# Out:
# (50261, 42)

# %%
faulty_twentyPercent_sample = combined_faulty_df.sample(frac=0.1, random_state=1)
faulty_eightyPercent_sample = combined_faulty_df.drop(faulty_twentyPercent_sample.index)

# %%
faulty_twentyPercent_sample.shape, faulty_eightyPercent_sample.shape
# Out:
# ((5026, 42), (45235, 42))

# %%
eighty_percent_training_data = [healthy_eightyPercent_sample, faulty_eightyPercent_sample]
eighty_percent_training_data = pd.concat(eighty_percent_training_data, ignore_index=True)

twenty_percent_testing_data = [healthy_twentyPercent_sample, faulty_twentyPercent_sample]
twenty_percent_testing_data = pd.concat(twenty_percent_testing_data, ignore_index=True)

# %%
eighty_percent_training_data.shape, twenty_percent_testing_data.shape
# Out:
# ((90240, 42), (10027, 42))

# %%
eighty_percent_training_data.to_csv('training_data.csv', index=False)
twenty_percent_testing_data.to_csv('testing_data.csv', index=False)
