# %%
import numpy as np
import pandas as pd

# %%
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.utils import shuffle
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score

# %%
from sklearn import svm
from sklearn.linear_model import SGDClassifier
from sklearn.neighbors import NearestNeighbors
from sklearn.naive_bayes import GaussianNB
from sklearn import tree

# %%
train_df = pd.read_csv("Extracted Features Train Test 70 30 Dataset Sampling 50/training_data.csv")
test_df = pd.read_csv("Extracted Features Train Test 70 30 Dataset Sampling 50/testing_data.csv")

# %%
train_df.shape, test_df.shape
# Out:
# ((28070, 42), (12030, 42))

# %%
train_df.columns
# Out:
# Index(['Mean_S1', 'RMS_S1', 'StdDev_S1', 'Variance_S1', 'Skewness_S1',
#        'Kurtosis_S1', 'PeakToPeak_S1', 'CrestFactor_S1', 'ShapeFactor_S1',
#        'ImpulseFactor_S1', 'Mean_S2', 'RMS_S2', 'StdDev_S2', 'Variance_S2',
#        'Skewness_S2', 'Kurtosis_S2', 'PeakToPeak_S2', 'CrestFactor_S2',
#        'ShapeFactor_S2', 'ImpulseFactor_S2', 'Mean_S3', 'RMS_S3', 'StdDev_S3',
#        'Variance_S3', 'Skewness_S3', 'Kurtosis_S3', 'PeakToPeak_S3',
#        'CrestFactor_S3', 'ShapeFactor_S3', 'ImpulseFactor_S3', 'Mean_S4',
#        'RMS_S4', 'StdDev_S4', 'Variance_S4', 'Skewness_S4', 'Kurtosis_S4',
#        'PeakToPeak_S4', 'CrestFactor_S4', 'ShapeFactor_S4', 'ImpulseFactor_S4',
#        'load', 'label'],
#       dtype='object')

# %%
x_train = train_df.drop(columns=['label'])
y_train = train_df['label']

# %%
x_train.shape, y_train.shape
# Out:
# ((28070, 41), (28070,))

# %%
x_test = test_df.drop(columns=['label'])
y_test = test_df['label']

# %%
from sklearn.preprocessing import StandardScaler

# Standardize the data
scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %%
x_test.shape, y_test.shape
# Out:
# ((12030, 41), (12030,))

# %%
from sklearn import svm

SVM_Model = svm.SVC()
SVM_Model.fit(x_train, y_train)
SVM_Model.score(x_test, y_test)
# Out:
# 0.913050706566916

# %%
y_pred = SVM_Model.predict(x_test)
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91      5895
#            1       0.92      0.91      0.91      6135
#
#     accuracy                           0.91     12030
#    macro avg       0.91      0.91      0.91     12030
# weighted avg       0.91      0.91      0.91     12030

# %%
DT_Model = tree.DecisionTreeClassifier()
DT_Model.fit(x_train, y_train)
DT_Model.score(x_test, y_test)
# Out:
# 0.8534497090606816

# %%
y_pred = DT_Model.predict(x_test)
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.85      0.85      6090
#            1       0.85      0.86      0.85      5940
#
#     accuracy                           0.85     12030
#    macro avg       0.85      0.85      0.85     12030
# weighted avg       0.85      0.85      0.85     12030

# %%
from sklearn.ensemble import RandomForestClassifier

RF_Model = RandomForestClassifier()
RF_Model.fit(x_train, y_train)
RF_Model.score(x_test, y_test)
# Out:
# 0.9098088113050706

# %%
y_pred = RF_Model.predict(x_test)
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91      5962
#            1       0.91      0.91      0.91      6068
#
#     accuracy                           0.91     12030
#    macro avg       0.91      0.91      0.91     12030
# weighted avg       0.91      0.91      0.91     12030

# %%
from sklearn.naive_bayes import GaussianNB

NB_Model = GaussianNB()
NB_Model.fit(x_train, y_train)
NB_Model.score(x_test, y_test)
# Out:
# 0.7026600166251039

# %%
y_pred = NB_Model.predict(x_test)
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.78      0.65      4338
#            1       0.84      0.66      0.74      7692
#
#     accuracy                           0.70     12030
#    macro avg       0.70      0.72      0.70     12030
# weighted avg       0.74      0.70      0.71     12030

# %%
from sklearn.linear_model import LogisticRegression

LR_Model = LogisticRegression()
LR_Model.fit(x_train, y_train)
LR_Model.score(x_test, y_test)
# Out:
# C:\Users\Apple Khan\.conda\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.8807980049875311

# %%
y_pred = LR_Model.predict(x_test)
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88      5977
#            1       0.88      0.88      0.88      6053
#
#     accuracy                           0.88     12030
#    macro avg       0.88      0.88      0.88     12030
# weighted avg       0.88      0.88      0.88     12030

# %%
from sklearn.neighbors import KNeighborsClassifier

KNN_Model = KNeighborsClassifier()
KNN_Model.fit(x_train, y_train)
KNN_Model.score(x_test, y_test)
# Out:
# 0.8652535328345802

# %%
y_pred = KNN_Model.predict(x_test)
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.87      0.86      5890
#            1       0.87      0.86      0.87      6140
#
#     accuracy                           0.87     12030
#    macro avg       0.87      0.87      0.87     12030
# weighted avg       0.87      0.87      0.87     12030

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

GBC_Model = GradientBoostingClassifier()
GBC_Model.fit(x_train, y_train)
GBC_Model.score(x_test, y_test)
# Out:
# 0.8931005818786367

# %%
y_pred = GBC_Model.predict(x_test)
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89      5891
#            1       0.90      0.89      0.89      6139
#
#     accuracy                           0.89     12030
#    macro avg       0.89      0.89      0.89     12030
# weighted avg       0.89      0.89      0.89     12030
