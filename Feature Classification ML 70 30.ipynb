# %%
import numpy as np
import pandas as pd

# %%
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.utils import shuffle
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score

# %%
from sklearn import svm
from sklearn.linear_model import SGDClassifier
from sklearn.neighbors import NearestNeighbors
from sklearn.naive_bayes import GaussianNB
from sklearn import tree

# %%
train_df = pd.read_csv("Extracted Features Train Test 70 30 Dataset/training_data.csv")
test_df = pd.read_csv("Extracted Features Train Test 70 30 Dataset/testing_data.csv")

# %%
train_df.shape, test_df.shape
# Out:
# ((14033, 42), (6014, 42))

# %%
train_df.columns
# Out:
# Index(['Mean_S1', 'RMS_S1', 'StdDev_S1', 'Variance_S1', 'Skewness_S1',
#        'Kurtosis_S1', 'PeakToPeak_S1', 'CrestFactor_S1', 'ShapeFactor_S1',
#        'ImpulseFactor_S1', 'Mean_S2', 'RMS_S2', 'StdDev_S2', 'Variance_S2',
#        'Skewness_S2', 'Kurtosis_S2', 'PeakToPeak_S2', 'CrestFactor_S2',
#        'ShapeFactor_S2', 'ImpulseFactor_S2', 'Mean_S3', 'RMS_S3', 'StdDev_S3',
#        'Variance_S3', 'Skewness_S3', 'Kurtosis_S3', 'PeakToPeak_S3',
#        'CrestFactor_S3', 'ShapeFactor_S3', 'ImpulseFactor_S3', 'Mean_S4',
#        'RMS_S4', 'StdDev_S4', 'Variance_S4', 'Skewness_S4', 'Kurtosis_S4',
#        'PeakToPeak_S4', 'CrestFactor_S4', 'ShapeFactor_S4', 'ImpulseFactor_S4',
#        'load', 'label'],
#       dtype='object')

# %%
x_train = train_df.drop(columns=['label'])
y_train = train_df['label']

# %%
x_train.shape, y_train.shape
# Out:
# ((14033, 41), (14033,))

# %%
x_test = test_df.drop(columns=['label'])
y_test = test_df['label']

# %%
from sklearn.preprocessing import StandardScaler

# Standardize the data
scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %%
x_test.shape, y_test.shape
# Out:
# ((6014, 41), (6014,))

# %%
from sklearn import svm

SVM_Model = svm.SVC()
SVM_Model.fit(x_train, y_train)
SVM_Model.score(x_test, y_test)
# Out:
# 0.9587628865979382

# %%
y_pred = SVM_Model.predict(x_test)
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      3003
#            1       0.96      0.96      0.96      3011
#
#     accuracy                           0.96      6014
#    macro avg       0.96      0.96      0.96      6014
# weighted avg       0.96      0.96      0.96      6014

# %%
DT_Model = tree.DecisionTreeClassifier()
DT_Model.fit(x_train, y_train)
DT_Model.score(x_test, y_test)
# Out:
# 0.9105420685068174

# %%
y_pred = DT_Model.predict(x_test)
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91      3003
#            1       0.91      0.91      0.91      3011
#
#     accuracy                           0.91      6014
#    macro avg       0.91      0.91      0.91      6014
# weighted avg       0.91      0.91      0.91      6014

# %%
from sklearn.ensemble import RandomForestClassifier

RF_Model = RandomForestClassifier()
RF_Model.fit(x_train, y_train)
RF_Model.score(x_test, y_test)
# Out:
# 0.9536082474226805

# %%
y_pred = RF_Model.predict(x_test)
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.95      3020
#            1       0.95      0.96      0.95      2994
#
#     accuracy                           0.95      6014
#    macro avg       0.95      0.95      0.95      6014
# weighted avg       0.95      0.95      0.95      6014

# %%
from sklearn.naive_bayes import GaussianNB

NB_Model = GaussianNB()
NB_Model.fit(x_train, y_train)
NB_Model.score(x_test, y_test)
# Out:
# 0.78084469571001

# %%
y_pred = NB_Model.predict(x_test)
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.84      0.76      2439
#            1       0.87      0.74      0.80      3575
#
#     accuracy                           0.78      6014
#    macro avg       0.78      0.79      0.78      6014
# weighted avg       0.80      0.78      0.78      6014

# %%
from sklearn.linear_model import LogisticRegression

LR_Model = LogisticRegression()
LR_Model.fit(x_train, y_train)
LR_Model.score(x_test, y_test)
# Out:
# C:\Users\Apple Khan\.conda\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.944296641170602

# %%
y_pred = LR_Model.predict(x_test)
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94      3004
#            1       0.94      0.95      0.94      3010
#
#     accuracy                           0.94      6014
#    macro avg       0.94      0.94      0.94      6014
# weighted avg       0.94      0.94      0.94      6014

# %%
from sklearn.neighbors import KNeighborsClassifier

KNN_Model = KNeighborsClassifier()
KNN_Model.fit(x_train, y_train)
KNN_Model.score(x_test, y_test)
# Out:
# 0.9255071499833721

# %%
y_pred = KNN_Model.predict(x_test)
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.93      0.92      2949
#            1       0.93      0.92      0.93      3065
#
#     accuracy                           0.93      6014
#    macro avg       0.93      0.93      0.93      6014
# weighted avg       0.93      0.93      0.93      6014

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

GBC_Model = GradientBoostingClassifier()
GBC_Model.fit(x_train, y_train)
GBC_Model.score(x_test, y_test)
# Out:
# 0.9489524442966412

# %%
y_pred = GBC_Model.predict(x_test)
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95      3008
#            1       0.95      0.95      0.95      3006
#
#     accuracy                           0.95      6014
#    macro avg       0.95      0.95      0.95      6014
# weighted avg       0.95      0.95      0.95      6014
